# %% [markdown]
# <a href="https://colab.research.google.com/github/raiadarsh0510/Software___Devlooopement/blob/main2/Day2Projject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = str(input("Enter names"))

# %%
entry= int(input("Number of Entry? "))

data = []

for i in range(entry):
    print(f"\nEntering data for entry {i+1}:")
    name = input("Enter name: ")
    mark = float(input("Enter mark: "))
    subject = input("Enter subject: ")

    data.append({"Name": name, "Mark": mark, "Subject": subject})

print("\nCollected Data:")
for entry in data:
    print(entry)
# Out:
# Number of Entry? 1
#
# Entering data for entry 1:
# Enter name: Adarsh
# Enter mark: 77
# Enter subject: Maths
#
# Collected Data:
# {'Name': 'Adarsh', 'Mark': 77.0, 'Subject': 'Maths'}

# %%
entry = int(input("Number of Students? "))

data = []

for i in range(entry):
    print(f"\nEntering data for Student {i+1}")

    name = input("Enter name: ")

    subjects = {}
    total_marks = 0

    sub_count = int(input("How many subjects? "))

    for j in range(sub_count):
        sub_name = input(f"Enter subject {j+1} name: ")
        mark = float(input(f"Enter marks for {sub_name}: "))
        subjects[sub_name] = mark
        total_marks += mark

    average = total_marks / sub_count

    # Grade system
    if average >= 90:
        grade = "A+"
    elif average >= 75:
        grade = "A"
    elif average >= 60:
        grade = "B"
    elif average >= 40:
        grade = "C"
    else:
        grade = "Fail"

    data.append({
        "Name": name,
        "Subjects": subjects,
        "Total": total_marks,
        "Average": average,
        "Grade": grade
    })

# FINAL MARKSHEET OUTPUT
print("\n" + "="*40)
print("FINAL MARKSHEET")
print("="*40)
print("\n" + "="*40)
print("SRMCEM")
print("="*40)

for student in data:
    print("\nName:", student["Name"])
    print("Subjects:")
    for sub, mark in student["Subjects"].items():
        print(f"  {sub}: {mark}")

    print("Total Marks:", student["Total"])
    print("Average:", student["Average"])
    print("Grade:", student["Grade"])
    print("-"*40)
# Out:
# Number of Students? 3
#
# Entering data for Student 1
# Enter name: ADARSH
# How many subjects? 3
# Enter subject 1 name: MATHS
# Enter marks for MATHS: 77
# Enter subject 2 name: SCIENCE
# Enter marks for SCIENCE: 67
# Enter subject 3 name: GK
# Enter marks for GK: 99
#
# Entering data for Student 2
# Enter name: DEVANSH
# How many subjects? 3
# Enter subject 1 name: MATHS
# Enter marks for MATHS: 67
# Enter subject 2 name: SCIENCE
# Enter marks for SCIENCE: 98
# Enter subject 3 name: GK
# Enter marks for GK: 76
#
# Entering data for Student 3
# Enter name: BADAL
# How many subjects? 3
# Enter subject 1 name: ATHS
# Enter marks for ATHS: 56
# Enter subject 2 name: SCIENCE
# Enter marks for SCIENCE: 78
# Enter subject 3 name: GK
# Enter marks for GK: 56
#
# ...
# FINAL MARKSHEET
# ...
#
# ...
# SRMCEM
# ...
#
# Name: ADARSH
# Subjects:
#   MATHS: 77.0
#   SCIENCE: 67.0
#   GK: 99.0
# Total Marks: 243.0
# Average: 81.0
# Grade: A
# ----------------------------------------
#
# Name: DEVANSH
# Subjects:
# ...

# %%
entry = int(input("Number of Students? "))

# Take common subjects (ONLY ONCE)
sub_count = int(input("How many subjects (common for all)? "))

subjects_list = []

for i in range(sub_count):
    sub_name = input(f"Enter subject {i+1} name: ")
    subjects_list.append(sub_name)

data = []

# Student data entry
for i in range(entry):
    print(f"\nEntering data for Student {i+1}")

    name = input("Enter name: ")

    marks = {}
    total_marks = 0

    for sub in subjects_list:
        mark = float(input(f"Enter marks for {sub}: "))
        marks[sub] = mark
        total_marks += mark

    average = total_marks / sub_count

    # Grade system
    if average >= 90:
        grade = "A+"
    elif average >= 75:
        grade = "A"
    elif average >= 60:
        grade = "B"
    elif average >= 40:
        grade = "C"
    else:
        grade = "Fail"

    data.append({
        "Name": name,
        "Marks": marks,
        "Total": total_marks,
        "Average": average,
        "Grade": grade
    })

# FINAL MARKSHEET OUTPUT
print("\n" + "="*50)
print("SRMCEM FINAL MARKSHEET")
print("="*50)

for student in data:
    print("\nName:", student["Name"])
    print("Marks:")

    for sub, mark in student["Marks"].items():
        print(f"  {sub}: {mark}")

    print("Total Marks:", student["Total"])
    print("Average:", student["Average"])
    print("Grade:", student["Grade"])
    print("-"*50)
# Out:
# Number of Students? 3
# How many subjects (common for all)? 4
# Enter subject 1 name: MATHS
# Enter subject 2 name: SCIENCE
# Enter subject 3 name: GK
# Enter subject 4 name: HINDI
#
# Entering data for Student 1
# Enter name: ADARSH
# Enter marks for MATHS: 67
# Enter marks for SCIENCE: 65
# Enter marks for GK: 56
# Enter marks for HINDI: 89
#
# Entering data for Student 2
# Enter name: DEVANSH
# Enter marks for MATHS: 56
# Enter marks for SCIENCE: 78
# Enter marks for GK: 98
# Enter marks for HINDI: 45
#
# Entering data for Student 3
# Enter name: BADAL
# Enter marks for MATHS: 56
# Enter marks for SCIENCE: 98
# Enter marks for GK: 7
# Enter marks for HINDI: 99
#
# ...
# SRMCEM FINAL MARKSHEET
# ...
#
# Name: ADARSH
# Marks:
#   MATHS: 67.0
#   SCIENCE: 65.0
#   GK: 56.0
#   HINDI: 89.0
# Total Marks: 277.0
# Average: 69.25
# Grade: B
# --------------------------------------------------
#
# Name: DEVANSH
# Marks:
#   MATHS: 56.0
#   SCIENCE: 78.0
#   GK: 98.0
#   HINDI: 45.0
# ...

# %%
entry = int(input("Number of Students? "))

sub_count = int(input("How many subjects (common for all)? "))

subjects_list = []

for i in range(sub_count):
    sub_name = input(f"Enter subject {i+1} name: ")
    subjects_list.append(sub_name)

data = []

for i in range(entry):
    print(f"\nEntering data for Student {i+1}")

    name = input("Enter name: ")

    marks = {}
    total_marks = 0

    for sub in subjects_list:
        mark = float(input(f"Enter marks for {sub}: "))
        marks[sub] = mark
        total_marks += mark

    average = total_marks / sub_count

    # Grade system
    if average >= 90:
        grade = "A+"
    elif average >= 75:
        grade = "A"
    elif average >= 60:
        grade = "B"
    elif average >= 40:
        grade = "C"
    else:
        grade = "Fail"

    data.append({
        "Name": name,
        "Marks": marks,
        "Total": total_marks,
        "Average": average,
        "Grade": grade
    })

# ================= TABLE OUTPUT =================
print("\n" + "="*80)
print("SRMCEM FINAL MARKSHEET".center(80))
print("="*80)

# Header
header = f"{'Name':<15}"

for sub in subjects_list:
    header += f"{sub:<10}"

header += f"{'Total':<10}{'Avg':<10}{'Grade':<10}"

print(header)
print("-"*80)

# Data rows
for student in data:
    row = f"{student['Name']:<15}"

    for sub in subjects_list:
        row += f"{student['Marks'][sub]:<10}"

    row += f"{student['Total']:<10.2f}{student['Average']:<10.2f}{student['Grade']:<10}"

    print(row)

print("="*80)7
# Out:
# Number of Students? 3
# How many subjects (common for all)? 3
# Enter subject 1 name: MATHS
# Enter subject 2 name: SCIENCE
# Enter subject 3 name: HINDI
#
# Entering data for Student 1
# Enter name: ADARSH
# Enter marks for MATHS: 78
# Enter marks for SCIENCE: 76
# Enter marks for HINDI: 89
#
# Entering data for Student 2
# Enter name: DEVANSH
# Enter marks for MATHS: 87
# Enter marks for SCIENCE: 68
# Enter marks for HINDI: 89
#
# Entering data for Student 3
# Enter name: BADAL
# Enter marks for MATHS: 65
# Enter marks for SCIENCE: 98
# Enter marks for HINDI: 90
#
# ...
#                              SRMCEM FINAL MARKSHEET
# ...
# Name           MATHS     SCIENCE   HINDI     Total     Avg       Grade
# --------------------------------------------------------------------------------
# ADARSH         78.0      76.0      89.0      243.00    81.00     A
# DEVANSH        87.0      68.0      89.0      244.00    81.33     A
# BADAL          65.0      98.0      90.0      253.00    84.33     A
# ...

# %% [markdown]
# ***CALCULATOR:***

# %%
# Simple Calculator

print("===== SIMPLE CALCULATOR =====")
print("1. Addition (+)")
print("2. Subtraction (-)")
print("3. Multiplication (*)")
print("4. Division (/)")
print("5. Modulus (%)")
print("6. Exponent (**)")
print("7. Floor Division (//)")

choice = int(input("Enter your choice (1-7): "))

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

if choice == 1:
    print("Result =", num1 + num2)

elif choice == 2:
    print("Result =", num1 - num2)

elif choice == 3:
    print("Result =", num1 * num2)

elif choice == 4:
    if num2 != 0:
        print("Result =", num1 / num2)
    else:
        print("Error! Division by zero is not allowed.")

elif choice == 5:
    if num2 != 0:
        print("Result =", num1 % num2)
    else:
        print("Error! Modulus by zero is not allowed.")

elif choice == 6:
    print("Result =", num1 ** num2)

elif choice == 7:
    if num2 != 0:
        print("Result =", num1 // num2)
    else:
        print("Error! Floor division by zero is not allowed.")

else:
    print("Invalid Choice!")
# Out:
# ===== SIMPLE CALCULATOR =====
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (*)
# 4. Division (/)
# 5. Modulus (%)
# 6. Exponent (**)
# 7. Floor Division (//)
# Enter your choice (1-7): 4
# Enter first number: 987
# Enter second number: 987
# Result = 1.0

# %%
# Function definitions

def add(a, b):
    return a + b

def subtract(a, b):
    return a - b

def multiply(a, b):
    return a * b

def divide(a, b):
    if b != 0:
        return a / b
    return "Division by zero is not allowed."

# Main Program
print("===== SIMPLE CALCULATOR =====")
print("1. Addition")
print("2. Subtraction")
print("3. Multiplication")
print("4. Division")

choice = int(input("Enter your choice (1-4): "))

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

if choice == 1:
    print("Result =", add(num1, num2))

elif choice == 2:
    print("Result =", subtract(num1, num2))

elif choice == 3:
    print("Result =", multiply(num1, num2))

elif choice == 4:
    print("Result =", divide(num1, num2))

else:
    print("Invalid Choice!")
# Out:
# ===== SIMPLE CALCULATOR =====
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# Enter your choice (1-4): 3
# Enter first number: 6
# Enter second number: 7
# Result = 42.0

# %% [markdown]
# ***ATM PIN GENERATE***

# %%
from ast import Continue
import random

num = random.randint(0000, 9999)
print(f"{num:04d}")

pin = float(input("Enter PIN"))

if num == pin:
  Continue

  print("1. WITHDRAW")
  print("2. CHECK BALANCE")
  print("3. PIN ")
  print("4. TRANSFER")

  choice = int(input("Enter your choice (1-4): "))

  if choice == 1:

    amount = float(input("Enter Amount"))
    print("Withdraw Successful")

  elif choice == 2:
    amount = float(input("Enter Amount"))
    print("Check Balance Successful")

  elif choice == 3:
   amount = float(input("Enter Amount"))
   print("PIN Successful")

  elif choice == 4:
   amount = float(input("Enter Amount"))
   print("Transfer Successful")

  else:
    print("Invalid Choice!")
else:
  print("Invalid PIN")
# Out:
# 0495
# Enter PIN0495
# 1. WITHDRAW
# 2. CHECK BALANCE
# 3. PIN
# 4. TRANSFER
# Enter your choice (1-4): 4
# Enter Amount10000
# Transfer Successful

# %%
balance = 50000
pin = 1234

entered_pin = int(input("Enter your 4-digit PIN: "))

if entered_pin == pin:

    while True:
        print("\n========== ATM MENU ==========")
        print("1. Withdraw")
        print("2. Check Balance")
        print("3. Change PIN")
        print("4. Transfer Money")
        print("5. Exit")

        choice = int(input("Enter your choice: "))

        # Withdraw
        if choice == 1:
            print("\n----- Withdraw -----")
            print("Balance Before Withdrawal:", balance)

            amount = float(input("Enter withdrawal amount: "))

            if amount <= 0:
                print("Invalid amount.")

            elif amount > balance:
                print("Insufficient Balance.")

            else:
                balance -= amount
                print("Withdrawal Successful.")
                print("Amount Withdrawn:", amount)
                print("Balance After Withdrawal:", balance)

        # Check Balance
        elif choice == 2:
            print("\n----- Account Balance -----")
            print("Current Balance:", balance)

        # Change PIN
        elif choice == 3:
            print("\n----- Change PIN -----")
            old_pin = int(input("Enter Current PIN: "))

            if old_pin == pin:
                new_pin = int(input("Enter New PIN: "))
                confirm_pin = int(input("Confirm New PIN: "))

                if new_pin == confirm_pin:
                    pin = new_pin
                    print("PIN Changed Successfully.")
                else:
                    print("PINs do not match.")
            else:
                print("Incorrect Current PIN.")

        # Transfer Money
        elif choice == 4:
            print("\n----- Money Transfer -----")

            account_number = input("Enter Receiver Account Number: ")

            if len(account_number) != 10 or not account_number.isdigit():
                print("Invalid Account Number.")
            else:
                print("Balance Before Transfer:", balance)

                amount = float(input("Enter Transfer Amount: "))

                if amount <= 0:
                    print("Invalid amount.")

                elif amount > balance:
                    print("Insufficient Balance.")

                else:
                    balance -= amount
                    print("Transfer Successful.")
                    print("Transferred Amount:", amount)
                    print("Receiver Account:", account_number)
                    print("Balance After Transfer:", balance)

        # Exit
        elif choice == 5:
            print("Thank you for using our ATM.")
            break

        else:
            print("Invalid Choice.")

else:
    print("Invalid PIN.")
# Out:
# Enter your 4-digit PIN: 1234
#
# ========== ATM MENU ==========
# 1. Withdraw
# 2. Check Balance
# 3. Change PIN
# 4. Transfer Money
# 5. Exit
# Enter your choice: 2
#
# ----- Account Balance -----
# Current Balance: 50000
#
# ========== ATM MENU ==========
# 1. Withdraw
# 2. Check Balance
# 3. Change PIN
# 4. Transfer Money
# 5. Exit
# Enter your choice: 1
#
# ----- Withdraw -----
# Balance Before Withdrawal: 50000
# Enter withdrawal amount: 51000
# Insufficient Balance.
#
# ========== ATM MENU ==========
# 1. Withdraw
# 2. Check Balance
# 3. Change PIN
# 4. Transfer Money
# 5. Exit
