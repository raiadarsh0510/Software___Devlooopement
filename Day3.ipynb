# %% [markdown]
# <a href="https://colab.research.google.com/github/raiadarsh0510/Software___Devlooopement/blob/main3/Day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***GENERATOR FUNCTION***

# %%
s="sudh"

# %%
s
# Out:
# 'sudh'

# %%
s1 = iter(s)

# %%
for i in s:
  print(i)
# Out:
# s
# u
# d
# h

# %%
s1 = iter(s)

# %%
type(s1)
# Out:
# str_ascii_iterator

# %%
next(s1)
# Out:
# 's'

# %%
next(s1)
# Out:
# 'u'

# %%
def count_test(n):
  count = 1
  while count <=n:
    yield count
    count = count +1

# %%
c=count_test(5)

# %%
print(c)
# Out:
# <generator object count_test at 0x7b860f5b2200>

# %%
type(c)
# Out:
# generator

# %%
for i in c:
  print(i)

# %%
def count_test(n):
  count = 1
  while count <=n:
    yield count
    count = count*3

# %%
c=count_test(5)

# %%
for i in c:
  print(i)
# Out:
# 1
# 3

# %%
def count_test(n):
  count = 1
  while count <=n:
    yield count
    count *= 3

# %%
c= count_test(5)

# %%
for i in c:
  print(i)
# Out:
# 1
# 3

# %%
def count_test(n):
    count = 1
    while count <= n:
        print(count)
        count *= 3

# %%
count_test(30)
# Out:
# 1
# 3
# 9
# 27

# %% [markdown]
# ***LAMBDA***

# %%
n=3
p=2

# %%
def test(n,p):
  return n**p

# %%
test(3,2)
# Out:
# 9

# %%
a = lambda n,p :n**p

# %%
a(3,5)
# Out:
# 243

# %%
add =lambda w,x,y,z :w+x+y+z

# %%
add(78,94,98865,2334467)
# Out:
# 2433504

# %%
sum =lambda w,x,y,z :w-x+y*z

# %%
sum(5,6,7,8)
# Out:
# 55

# %%
c_to_f = lambda c : (9/5)*c+32

# %%
c_to_f(56)
# Out:
# 132.8

# %%
f_to_c = lambda f : (f-32)*5/9

# %%
f_to_c(-45)
# Out:
# -42.77777777777778

# %%
finding_max = lambda x,y : x if x>y else y

# %%
finding_max(34,23)
# Out:
# 34

# %%
finding_min = lambda x,y : x if x<y else y

# %%
finding_min(34,23)
# Out:
# 23

# %%
s = "pwskills"

# %%
find_len = lambda s : len(s)

# %%
find_len(s)
# Out:
# 8

# %%
finding_min = lambda x,y,z : x if x<y and x<z else y if y<z else z

# %%
finding_min(3,5,2)
# Out:
# 2

# %%
finding_max = lambda x,y,z : x if x>y and x>z else y if y>z else z

# %%
finding_max(3,5,2)
# Out:
# 5
